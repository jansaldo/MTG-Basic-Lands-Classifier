# %% [markdown]
# # MTG -  Basic Lands Classifier
# ## Fetch Data
#
# In this notebook, we consume [Scryfall API](https://scryfall.com/docs/api) in order to fetch the available images of basic lands which we'll use to develop our classification model.

# %%
import os
import pandas as pd
from joblib import Parallel, delayed
from multiprocessing import cpu_count
from requests import get
from shutil import copyfileobj
from tqdm import tqdm

pd.set_option('display.max_rows', 150)

# %%
# Fetch bulk data from Scryfall
bulk = ' https://api.scryfall.com/bulk-data'
response = get(bulk)
response.json()
# Out:
# {'object': 'list',
#  'has_more': False,
#  'data': [{'object': 'bulk_data',
#    'id': '27bf3214-1271-490b-bdfe-c0be6c23d02e',
#    'type': 'oracle_cards',
#    'updated_at': '2022-01-17T10:03:58.341+00:00',
#    'uri': 'https://api.scryfall.com/bulk-data/27bf3214-1271-490b-bdfe-c0be6c23d02e',
#    'name': 'Oracle Cards',
#    'description': 'A JSON file containing one Scryfall card object for each Oracle ID on Scryfall. The chosen sets for the cards are an attempt to return the most up-to-date recognizable version of the card.',
#    'compressed_size': 13183051,
#    'download_uri': 'https://c2.scryfall.com/file/scryfall-bulk/oracle-cards/oracle-cards-20220117100358.json',
#    'content_type': 'application/json',
#    'content_encoding': 'gzip'},
#   {'object': 'bulk_data',
#    'id': '6bbcf976-6369-4401-88fc-3a9e4984c305',
#    'type': 'unique_artwork',
#    'updated_at': '2022-01-17T10:13:55.857+00:00',
#    'uri': 'https://api.scryfall.com/bulk-data/6bbcf976-6369-4401-88fc-3a9e4984c305',
#    'name': 'Unique Artwork',
#    'description': 'A JSON file of Scryfall card objects that together contain all unique artworks. The chosen cards promote the best image scans.',
#    'compressed_size': 16305755,
#    'download_uri': 'https://c2.scryfall.com/file/scryfall-bulk/unique-artwork/unique-artwork-20220117101355.json',
#    'content_type': 'application/json',
#    'content_encoding': 'gzip'},
#   {'object': 'bulk_data',
#    'id': 'e2ef41e3-5778-4bc2-af3f-78eca4dd9c23',
#    'type': 'default_cards',
#    'updated_at': '2022-01-17T10:02:44.439+00:00',
#    'uri': 'https://api.scryfall.com/bulk-data/e2ef41e3-5778-4bc2-af3f-78eca4dd9c23',
#    'name': 'Default Cards',
#    'description': 'A JSON file containing every card object on Scryfall in English or the printed language if the card is only available in one language.',
#    'compressed_size': 33870708,
#    'download_uri': 'https://c2.scryfall.com/file/scryfall-bulk/default-cards/default-cards-20220117100244.json',
#    'content_type': 'application/json',
#    'content_encoding': 'gzip'},
#   {'object': 'bulk_data',
#    'id': '922288cb-4bef-45e1-bb30-0c2bd3d3534f',
#    'type': 'all_cards',
#    'updated_at': '2022-01-17T10:12:33.898+00:00',
#    'uri': 'https://api.scryfall.com/bulk-data/922288cb-4bef-45e1-bb30-0c2bd3d3534f',
#    'name': 'All Cards',
#    'description': 'A JSON file containing every card object on Scryfall in every language.',
#    'compressed_size': 212627426,
#    'download_uri': 'https://c2.scryfall.com/file/scryfall-bulk/all-cards/all-cards-20220117101233.json',
#    'content_type': 'application/json',
#    'content_encoding': 'gzip'},
#   {'object': 'bulk_data',
#    'id': '06f54c0b-ab9c-452d-b35a-8297db5eb940',
#    'type': 'rulings',
#    'updated_at': '2022-01-17T10:04:08.744+00:00',
#    'uri': 'https://api.scryfall.com/bulk-data/06f54c0b-ab9c-452d-b35a-8297db5eb940',
#    'name': 'Rulings',
#    'description': 'A JSON file containing all Rulings on Scryfall. Each ruling refers to cards via an `oracle_id`.',
#    'compressed_size': 3062678,
#    'download_uri': 'https://c2.scryfall.com/file/scryfall-bulk/rulings/rulings-20220117100408.json',
#    'content_type': 'application/json',
#    'content_encoding': 'gzip'}]}

# %%
# Fetch unique artworks
download_uri = response.json()['data'][1]['download_uri']
response = get(download_uri)
df = pd.DataFrame(response.json())

# %%
# First rows of the table
df.head()
# Out:
#   object                                    id  \
# 0   card  0000579f-7b35-4ed3-b44c-db2a538066fe
# 1   card  00006596-1166-4a79-8443-ca9f82e6db4e
# 2   card  0000cd57-91fe-411f-b798-646e965eec37
# 3   card  0001f1ef-b957-4a55-b47f-14839cdbab6f
# 4   card  00020b05-ecb9-4603-8cc1-8cfa7a14befc
#
#                               oracle_id multiverse_ids  mtgo_id  mtgo_foil_id  \
# 0  44623693-51d6-49ad-8cd7-140505caf02f       [109722]  25527.0       25528.0
# 1  8ae3562f-28b7-4462-96ed-be0cf7052ccc       [189637]  34586.0       34587.0
# 2  9f0d82ae-38bf-45d8-8cda-982b6ead1d72       [435231]  65170.0       65171.0
# 3  ef027846-be81-4959-a6b5-56bd01b1e68a       [472997]  78170.0           NaN
# 4  d96ac790-428b-4a64-8dbd-6baa73eb6210       [394089]      NaN           NaN
#
#    tcgplayer_id  cardmarket_id              name lang  ... color_indicator  \
# 0       14240.0        13850.0       Fury Sliver   en  ...             NaN
# 1       33347.0        21851.0     Kor Outfitter   en  ...             NaN
# 2      145764.0       301766.0     Siren Lookout   en  ...             NaN
# 3      198861.0       400134.0  Venerable Knight   en  ...             NaN
# 4       95585.0       272052.0          Wildcall   en  ...             NaN
#
#   life_modifier hand_modifier tcgplayer_etched_id  content_warning  \
# 0           NaN           NaN                 NaN              NaN
# 1           NaN           NaN                 NaN              NaN
# 2           NaN           NaN                 NaN              NaN
# 3           NaN           NaN                 NaN              NaN
# 4           NaN           NaN                 NaN              NaN
#
#   printed_name printed_type_line printed_text  variation_of flavor_name
# 0          NaN               NaN          NaN           NaN         NaN
# 1          NaN               NaN          NaN           NaN         NaN
# 2          NaN               NaN          NaN           NaN         NaN
# 3          NaN               NaN          NaN           NaN         NaN
# 4          NaN               NaN          NaN           NaN         NaN
#
# [5 rows x 82 columns]

# %%
# Basic info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30893 entries, 0 to 30892
# Data columns (total 82 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   object               30893 non-null  object
#  1   id                   30893 non-null  object
#  2   oracle_id            30888 non-null  object
#  3   multiverse_ids       30893 non-null  object
#  4   mtgo_id              22662 non-null  float64
#  5   mtgo_foil_id         16827 non-null  float64
#  6   tcgplayer_id         29504 non-null  float64
#  7   cardmarket_id        28198 non-null  float64
#  8   name                 30893 non-null  object
#  9   lang                 30893 non-null  object
#  10  released_at          30893 non-null  object
#  11  uri                  30893 non-null  object
#  12  scryfall_uri         30893 non-null  object
#  13  layout               30893 non-null  object
#  14  highres_image        30893 non-null  bool
#  15  image_status         30893 non-null  object
#  16  image_uris           30008 non-null  object
#  17  mana_cost            30008 non-null  object
#  18  cmc                  30888 non-null  float64
#  19  type_line            30888 non-null  object
#  20  oracle_text          29820 non-null  object
#  21  power                14810 non-null  object
#  22  toughness            14810 non-null  object
#  23  colors               30008 non-null  object
#  24  color_identity       30893 non-null  object
#  25  keywords             30893 non-null  object
#  26  legalities           30893 non-null  object
#  27  games                30893 non-null  object
#  28  reserved             30893 non-null  bool
#  29  foil                 30893 non-null  bool
#  30  nonfoil              30893 non-null  bool
#  31  finishes             30893 non-null  object
#  32  oversized            30893 non-null  bool
#  33  promo                30893 non-null  bool
#  34  reprint              30893 non-null  bool
#  35  variation            30893 non-null  bool
#  36  set_id               30893 non-null  object
#  37  set                  30893 non-null  object
#  38  set_name             30893 non-null  object
#  39  set_type             30893 non-null  object
#  40  set_uri              30893 non-null  object
#  41  set_search_uri       30893 non-null  object
#  42  scryfall_set_uri     30893 non-null  object
#  43  rulings_uri          30893 non-null  object
#  44  prints_search_uri    30893 non-null  object
#  45  collector_number     30893 non-null  object
#  46  digital              30893 non-null  bool
#  47  rarity               30893 non-null  object
#  48  flavor_text          17286 non-null  object
#  49  card_back_id         30008 non-null  object
#  50  artist               30893 non-null  object
#  51  artist_ids           30890 non-null  object
#  52  illustration_id      30007 non-null  object
#  53  border_color         30893 non-null  object
#  54  frame                30893 non-null  object
#  55  full_art             30893 non-null  bool
#  56  textless             30893 non-null  bool
#  57  booster              30893 non-null  bool
#  58  story_spotlight      30893 non-null  bool
#  59  edhrec_rank          27425 non-null  float64
#  60  prices               30893 non-null  object
#  61  related_uris         30893 non-null  object
#  62  arena_id             5418 non-null   float64
#  63  preview              4494 non-null   object
#  64  security_stamp       5338 non-null   object
#  65  promo_types          2717 non-null   object
#  66  produced_mana        3626 non-null   object
#  67  watermark            2970 non-null   object
#  68  all_parts            2759 non-null   object
#  69  loyalty              470 non-null    object
#  70  frame_effects        1949 non-null   object
#  71  card_faces           1073 non-null   object
#  72  color_indicator      39 non-null     object
#  73  life_modifier        118 non-null    object
#  74  hand_modifier        118 non-null    object
#  75  tcgplayer_etched_id  187 non-null    float64
#  76  content_warning      9 non-null      object
#  77  printed_name         179 non-null    object
#  78  printed_type_line    123 non-null    object
#  79  printed_text         117 non-null    object
#  80  variation_of         13 non-null     object
#  81  flavor_name          42 non-null     object
# dtypes: bool(13), float64(8), object(61)
# memory usage: 16.6+ MB

# %%
# Filter basic lands
basics = df.loc[df['name'].isin(['Forest', 'Island', 'Mountain', 'Plains', 'Swamp']),
                ['id', 'name', 'released_at', 'image_uris', 'set_name', 'collector_number', 'artist']] \
           .sort_values(['released_at', 'set_name', 'collector_number'])

# %%
# Extract 'art_crop_uri'
basics['art_crop_uri'] = basics['image_uris'].apply(lambda x: x['art_crop'])

# %%
# Random sample of the dataset
basics.sample(5)
# Out:
#                                          id    name released_at  \
# 29061  f108b0fb-420a-422d-ae85-9a99c0f73169   Swamp  2017-12-08
# 16563  8a136975-e513-4c50-9d4a-855d03630470  Plains  1998-06-24
# 27420  e3133726-0eda-480c-9d67-64719cb77f1d   Swamp  2008-10-03
# 26239  d92ef517-2417-43a2-8b1a-0673d1531c65  Plains  2019-05-03
# 9678   51852e9d-9183-4f9a-a724-cb60cf677e38  Island  2013-09-27
#
#                                               image_uris           set_name  \
# 29061  {'small': 'https://c1.scryfall.com/file/scryfa...           Unstable
# 16563  {'small': 'https://c1.scryfall.com/file/scryfa...  Portal Second Age
# 27420  {'small': 'https://c1.scryfall.com/file/scryfa...    Shards of Alara
# 26239  {'small': 'https://c1.scryfall.com/file/scryfa...   War of the Spark
# 9678   {'small': 'https://c1.scryfall.com/file/scryfa...             Theros
#
#       collector_number          artist  \
# 29061              214       John Avon
# 16563              152     Fred Fields
# 27420              241  Aleksi Briclot
# 26239              250     Jonas De Ro
# 9678               237    Raoul Vitale
#
#                                             art_crop_uri
# 29061  https://c1.scryfall.com/file/scryfall-cards/ar...
# 16563  https://c1.scryfall.com/file/scryfall-cards/ar...
# 27420  https://c1.scryfall.com/file/scryfall-cards/ar...
# 26239  https://c1.scryfall.com/file/scryfall-cards/ar...
# 9678   https://c1.scryfall.com/file/scryfall-cards/ar...

# %%
# Basic info
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1246 entries, 21429 to 29093
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1246 non-null   object
#  1   name              1246 non-null   object
#  2   released_at       1246 non-null   object
#  3   image_uris        1246 non-null   object
#  4   set_name          1246 non-null   object
#  5   collector_number  1246 non-null   object
#  6   artist            1246 non-null   object
#  7   art_crop_uri      1246 non-null   object
# dtypes: object(8)
# memory usage: 87.6+ KB

# %%
# Function to get the images
def get_img(dst_dir, img_uri, fname):
    """Downloads an image from a given URI.
    
    Parameters
    ----------
    dst_dir : str
        Destination directory of the image.
    img_uri : srt
        URI from where the image is downloaded.
    fname : str
        Filename of the image.
    """
    # Filename path
    fname_path = os.path.join(dst_dir, f"{fname}.jpg")
    
    # Download the image in case we don't have it already
    if not os.path.exists(fname_path):
        try:
            with open(fname_path, 'wb') as out_file:
                copyfileobj(get(img_uri, stream=True).raw, out_file)
        except:
            pass

# %%
# Directory in which we'll save the images
data_dir = 'data/imgs'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# Parallelize the tasks of getting the images
executor = Parallel(n_jobs=cpu_count())
tasks = (delayed(get_img)(data_dir, img_uri, idx) for (img_uri, idx) in
         tqdm(zip(basics['art_crop_uri'], basics['id'])))
execution = executor(tasks)
# Out:
# 1246it [00:00, 1992.15it/s]

# %%
# Check whether we've successfully downloaded every image in the dataset
len(os.listdir(data_dir)) == len(basics)
# Out:
# True

# %%
# Export basics DataFrame to csv
basics.to_csv('data/basic_lands_artworks.csv', index=False)
